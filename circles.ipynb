# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
r = 1.0

# %%
x = np.linspace(-r, r, 1000)

# %%
r = 1.0

# %%
y = np.sqrt(r**2 - x**2)

# %%
_, ax = plt.subplots(figsize=(6, 3))

ax.plot(x, y)

# %%
(-1.0)**0.5
# Out:
# (6.123233995736766e-17+1j)

# %%
np.array([-1.0])**0.5
# Out:
# /var/folders/p5/gbbj70z56s93crkg2tqz_k740000gn/T/ipykernel_953/106168073.py:1: RuntimeWarning: invalid value encountered in sqrt
#   np.array([-1.0])**0.5
# array([nan])

# %% [markdown]
# ***
#
# #### End
