# %%
import matplotlib.pyplot as plt

import numpy as np

plt.style.use('./ian.mplstyle')

# %%
x = np.linspace(-3.0 * np.pi, 6.0 * np.pi, 1000)

y = np.sin(x)

# %%
fig, ax = plt.subplots(figsize=(10, 2))

ax.plot(x, y, 'purple')

ax.set_aspect("equal");
